# %% [markdown]
# Note that both command pip install ... have to be run in separate cells

# %%
pip install azure-eventhub
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: azure-eventhub in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (5.11.1)
# Requirement already satisfied: typing-extensions&gt;=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-eventhub) (4.5.0)
# Requirement already satisfied: azure-core&lt;2.0.0,&gt;=1.14.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-eventhub) (1.26.3)
# Requirement already satisfied: requests&gt;=2.18.4 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-eventhub) (2.25.1)
# Requirement already satisfied: six&gt;=1.11.0 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-eventhub) (1.15.0)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-eventhub) (1.25.11)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-eventhub) (2020.12.5)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-eventhub) (4.0.0)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-eventhub) (2.10)
# Python interpreter will be restarted.
# </div>

# %%
pip install azure-servicebus
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: azure-servicebus in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (7.8.2)
# Requirement already satisfied: azure-core&lt;2.0.0,&gt;=1.14.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-servicebus) (1.26.3)
# Requirement already satisfied: isodate&gt;=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-servicebus) (0.6.1)
# Requirement already satisfied: uamqp&lt;2.0.0,&gt;=1.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-servicebus) (1.6.4)
# Requirement already satisfied: msrest&lt;2.0.0,&gt;=0.6.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-servicebus) (0.7.1)
# Requirement already satisfied: typing-extensions&gt;=3.7.4.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-servicebus) (4.5.0)
# Requirement already satisfied: azure-common~=1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from azure-servicebus) (1.1.28)
# Requirement already satisfied: requests&gt;=2.18.4 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-servicebus) (2.25.1)
# Requirement already satisfied: six&gt;=1.11.0 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-servicebus) (1.15.0)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from msrest&lt;2.0.0,&gt;=0.6.17-&gt;azure-servicebus) (2020.12.5)
# Requirement already satisfied: requests-oauthlib&gt;=0.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from msrest&lt;2.0.0,&gt;=0.6.17-&gt;azure-servicebus) (1.3.1)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-servicebus) (1.25.11)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-servicebus) (4.0.0)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.14.0-&gt;azure-servicebus) (2.10)
# Requirement already satisfied: oauthlib&gt;=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6892a4d-629d-40f3-9161-731ab4bdce3c/lib/python3.8/site-packages (from requests-oauthlib&gt;=0.5.0-&gt;msrest&lt;2.0.0,&gt;=0.6.17-&gt;azure-servicebus) (3.2.2)
# Python interpreter will be restarted.
# </div>

# %%
import asyncio
from azure.eventhub.aio import EventHubProducerClient
from azure.eventhub import EventData
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# async def run():
#
#     producer = EventHubProducerClient.from_connection_string(conn_str="Endpoint=sb://db-eventhub-namespace.servicebus.windows.net/;SharedAccessKeyName=RootManageSharedAccessKey;SharedAccessKey=86ATi9XElcqYcspgAo8KNdXzMiWsSJbj++AEhA35NY8=", eventhub_name="eventhub-ratings")
#
#     async with producer:
#
#         event_data_batch = await producer.create_batch()
#
#         event_data_batch.add(EventData('{ "name": "Star Wars: Episode V - The Empire Strikes Back", "rating": "PG", "score": 8.2}'))
#         event_data_batch.add(EventData('{ "name": "Fame", "rating": "R", "score": 6.6}'))
#         event_data_batch.add(EventData('{ "name": "Friday the 13th", "rating": "R", "score": 6.1}'))
#
#         await producer.send_batch(event_data_batch)
#
# loop = asyncio.get_event_loop()
# loop.run_until_complete(run())

# %% [markdown]
# #add more events
# async def run():
#
#     producer = EventHubProducerClient.from_connection_string(conn_str="Endpoint=sb://db-eventhub-namespace.servicebus.windows.net/;SharedAccessKeyName=RootManageSharedAccessKey;SharedAccessKey=86ATi9XElcqYcspgAo8KNdXzMiWsSJbj++AEhA35NY8=", eventhub_name="eventhub-ratings")
#
#     async with producer:
#
#         event_data_batch = await producer.create_batch()
#         event_data_batch.add(EventData('{ "name": "Lagaan", "rating": "PG", "score": 9.2 }'))
#         event_data_batch.add(EventData('{ "name": "Andhadhun", "rating": "PG", "score": 8.4 }'))
#         event_data_batch.add(EventData('{ "name": "Airplane!","rating": "PG", "score": 7.7 }'))
#         event_data_batch.add(EventData('{ "name": "Caddyshack", "rating": "R", "score": 7.3 }'))
#         event_data_batch.add(EventData('{ "name": "Friday the 13th", "rating": "R", "score": 6.4}'))
#         event_data_batch.add(EventData('{ "name": "The Blues Brothers", "rating": "R", "score": 7.9}'))
#         event_data_batch.add(EventData('{ "name": "Raging Bull", "rating": "R", "score": 8.2 }'))
#         event_data_batch.add(EventData('{ "name": "Star Wars: Episode V - The Empire Strikes Back", "rating": "PG", "score": 8.2}'))
#         event_data_batch.add(EventData('{ "name": "Fame", "rating": "R", "score": 6.6}'))
#         event_data_batch.add(EventData('{ "name": "Friday the 13th", "rating": "R", "score": 6.1}'))
#
#         await producer.send_batch(event_data_batch)
#
# loop = asyncio.get_event_loop()
# loop.run_until_complete(run())

# %%
# add few more records
async def run():
    
    producer = EventHubProducerClient.from_connection_string(conn_str="Endpoint=sb://db-eventhub-namespace.servicebus.windows.net/;SharedAccessKeyName=RootManageSharedAccessKey;SharedAccessKey=86ATi9XElcqYcspgAo8KNdXzMiWsSJbj++AEhA35NY8=", eventhub_name="eventhub-ratings")
    
    async with producer:
        event_data_batch = await producer.create_batch()
        event_data_batch.add(EventData('{ "name": "Star Wars: Episode V - The Empire Strikes Back", "rating": "PG", "score": 8.2}'))
        event_data_batch.add(EventData('{ "name": "Fame", "rating": "R", "score": 6.6}'))
        event_data_batch.add(EventData('{ "name": "Friday the 13th", "rating": "R", "score": 6.1}'))
        

        await producer.send_batch(event_data_batch)

loop = asyncio.get_event_loop()
loop.run_until_complete(run())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
